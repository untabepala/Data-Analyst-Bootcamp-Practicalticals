# %%
import pandas as pd

# %% [markdown]
# # creating dataset

# %%
mydataset={'cars':["BMW","Volvo","Ford"],'passings':[3,7,2]}

# %%
myvar=pd.DataFrame(mydataset)
print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %% [markdown]
# # cheking pandas version

# %%
#print(pd._version_)

# %% [markdown]
# # creating pandas series from a list

# %%
a=[1,6,4]
myvar=pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    6
# 2    4
# dtype: int64

# %%
print(myvar[0])
print(myvar[1])
print(myvar[2])
# Out:
# 1
# 6
# 4

# %%
myvar=pd.Series(a, index=["x","y","z"])
print(myvar)
# Out:
# x    1
# y    6
# z    4
# dtype: int64

# %%
print(myvar["y"])
# Out:
# 6

# %% [markdown]
# # creating pandas series from a dictionary

# %%
calories={"day1":420,"day2":380,"day3":390}
myvar=pd.Series(calories)
print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
myvar=pd.Series(calories,index=["day1","day2"])
print(myvar)
# Out:
# day1    420
# day2    380
# dtype: int64

# %%
data={
    "calories":[420,380,390],"duration":[50,40,45]
}
myvar=pd.DataFrame(data)
print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
data={
    "calories":[420,380,390],"duration":[50,40,45]
}
df=pd.DataFrame(data)
print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
print(df.loc[0])
# Out:
# calories    420
# duration     50
# Name: 0, dtype: int64

# %% [markdown]
# # Load files into a DataFrame

# %%
#df=pd.read_csv('data.csv')
#print(df)

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
#df=pd.read_json('data.json')
#print(df.to_string())

# %%
data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
print(df.head(3))
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340

# %%
print(df.tail())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  6 non-null      int64
#  1   Pulse     6 non-null      int64
#  2   Maxpulse  6 non-null      int64
#  3   Calories  6 non-null      int64
# dtypes: int64(4)
# memory usage: 240.0+ bytes
# None

# %%
new_df=df.dropna()
print(new_df.to_string())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
df.fillna(130, inplace=True)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  6 non-null      int64
#  1   Pulse     6 non-null      int64
#  2   Maxpulse  6 non-null      int64
#  3   Calories  6 non-null      int64
# dtypes: int64(4)
# memory usage: 240.0+ bytes
# None

# %%
x=df["Calories"].mean()
df["Calories"].fillna(x,inplace=True)
print(df.to_string())
#empty values wlt mean ek add kirima
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
#empty values wlt median ek add kirima
x=df["Calories"].median()
df["Calories"].fillna(x, inplace=True)
print(df.to_string())
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %%
x=df["Calories"].mode()[0]
df["Calories"].fillna(x, inplace=True)
print(df.to_string())
# Out:
#    Duration  Pulse Maxpulse  Calories
# 0        60    110      130       409
# 1        60    117       AB       479
# 2        60    103      135       340
# 3        45    109      175       282
# 4        45    117      148       406
# 5        60    102      127       300

# %%
import pandas as pd
file_path = r'C:\Users\Nayani Tharushika\PycharmProjects\csv files\data.csv'
df = pd.read_csv(file_path)
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.loc[3,'Duration']=40

# %%
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          40    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
for x in df.index:
    if df.loc[x,"Duration"]>50:
        df.loc[x,"Duration"]=44
        print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          44    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          40    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]
#      Duration  Pulse  Maxpulse  Calories
# 0          44    110       130     409.1
# 1          44    117       145     479.0
# 2          60    103       135     340.0
# 3          40    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# ...

# %%
for x in df.index:
    if df.loc[x,"Duration"]>50:
        df.drop(x, inplace=True)
        print(df.to_string())

# %%
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# Length: 169, dtype: bool

# %%
df.drop_duplicates(inplace=True)
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          44    110       130     409.1
# 1          44    117       145     479.0
# 2          44    103       135     340.0
# 3          40    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        44    105       140     290.8
# 165        44    110       145     300.0
# 166        44    115       145     310.2
# 167        44    120       150     320.4
# 168        44    125       150     330.4
#
# [162 rows x 4 columns]

# %%
#calculates the relationship between each column set
print(df.corr())
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.266642 -0.158698  0.338310
# Pulse    -0.266642  1.000000  0.787035  0.015301
# Maxpulse -0.158698  0.787035  1.000000  0.195309
# Calories  0.338310  0.015301  0.195309  1.000000

# %%
df.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 df.plot()
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import matplotlib
matplotlib.use('TkAgg')
import pandas as pd
import matplotlib.pyplot as plt
df.plot(kind='scatter',x='Duration',y='Calories')
plt.show()

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import pandas as pd
import matplotlib.pyplot as plt

df["Duration"].plot(kind = 'hist')

plt.show()
# Out:
# C:\Users\Nayani Tharushika\AppData\Local\Temp\ipykernel_11564\511367604.py:10: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
